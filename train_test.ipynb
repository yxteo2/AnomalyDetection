# %%
import torch

ckpt = torch.load(r"C:\YuXuan\selfff\checkpoints\candle\candle\ssn\best_model.pth", map_location="cpu")
sd = ckpt["model_state_dict"]
for k in list(sd.keys())[:40]:
    print(k)
# Out:
# extractor.net.conv1.weight
# extractor.net.bn1.weight
# extractor.net.bn1.bias
# extractor.net.bn1.running_mean
# extractor.net.bn1.running_var
# extractor.net.bn1.num_batches_tracked
# extractor.net.layer1.0.conv1.weight
# extractor.net.layer1.0.bn1.weight
# extractor.net.layer1.0.bn1.bias
# extractor.net.layer1.0.bn1.running_mean
# extractor.net.layer1.0.bn1.running_var
# extractor.net.layer1.0.bn1.num_batches_tracked
# extractor.net.layer1.0.conv2.weight
# extractor.net.layer1.0.bn2.weight
# extractor.net.layer1.0.bn2.bias
# extractor.net.layer1.0.bn2.running_mean
# extractor.net.layer1.0.bn2.running_var
# extractor.net.layer1.0.bn2.num_batches_tracked
# extractor.net.layer1.1.conv1.weight
# extractor.net.layer1.1.bn1.weight
# extractor.net.layer1.1.bn1.bias
# extractor.net.layer1.1.bn1.running_mean
# extractor.net.layer1.1.bn1.running_var
# extractor.net.layer1.1.bn1.num_batches_tracked
# extractor.net.layer1.1.conv2.weight
# extractor.net.layer1.1.bn2.weight
# ...
